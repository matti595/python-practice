# %% [markdown]
# ## 6-1 Python模块

# %%
import math_operations
sum_result = math_operations.add(10, 5)
product_result = math_operations.multiply(10, 5)

# %%
print(sum_result, product_result,)
# Out:
# 15 50

# %% [markdown]
# ## 6-2 编写模块

# %%
from greetings import say_hello, say_goodbye
    # 测试模块功能
print(say_hello("Alice"))
print(say_goodbye("Bob"))
# Out:
# Greetings module is loaded.
# Hello Alice!
# Goodbye Bob!
